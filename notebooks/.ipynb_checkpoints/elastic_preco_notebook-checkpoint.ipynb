# %% [markdown]
# # 0.0 Import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from IPython.core.display import HTML
import statsmodels.api as sm
import inflection

# %% [markdown]
# ## 0.1 Helper Functions

# %%
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline

    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()

# %%
jupyter_settings()
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## 0.2 Loading Data

# %%
# Loading Dataset
df_raw = pd.read_csv('../data/df_ready.csv')

# %%
df_raw.sample()
# Out:
#       Unnamed: 0             Date_imp  Date_imp_d  Cluster                    Category_name                                      name   price  disc_price          merchant condition  Disc_percentage isSale  Imp_count brand                                      p_description currency             dateAdded                                           dateSeen           dateUpdated imageURLs manufacturer                                          shipping                                         sourceURLs       weight Date_imp_d.1     Day_n  month   month_n  day  Week_Number  Zscore_1   price_std
# 5416        7379  2017-12-07 20:00:00  2017/12/07       43  microphone, musical, instrument  RODE - NTG1 Condenser Shotgun Microphone  309.95      309.95  bhphotovideo.com       New              0.0     No         11  RODE  Pro Audio,Shotgun Microphones,Condenser Microp...      USD  2015-08-18T18:37:17Z  2017-08-22T01:00:00Z,2017-08-19T03:00:00Z,2018...  2018-06-13T20:13:03Z       NaN         RODE  Free Expedited Shipping for most orders over $49  https://www.bhphotovideo.com/c/product/400812-...  0.23 pounds   2017/12/07  Thursday     12  December    7           49 -0.469258  149.513063

# %% [markdown]
# ### 0.2.1 Drop Columns

# %%
# Drop useless column
df_raw = df_raw.drop( ['Unnamed: 0', 'Cluster',
        'condition','Disc_percentage', 'isSale', 'Imp_count', 'p_description',
       'currency', 'dateAdded', 'dateSeen', 'dateUpdated', 'imageURLs',
       'shipping', 'sourceURLs', 'weight', 'Date_imp', 'Date_imp_d.1',
       'Zscore_1','price_std'], axis=1 )

# %%
df_raw.head()
# Out:
#    Date_imp_d                 Category_name                                               name  price  disc_price     merchant    brand manufacturer     Day_n  month    month_n  day  Week_Number
# 0  2017/12/14  speaker, portable, bluetooth  Boytone - 2500W 2.1-Ch. Home Theater System - ...  69.00       64.99  Walmart.com  Boytone      Boytone  Thursday     12   December   14           50
# 1  2017/09/08  speaker, portable, bluetooth  Boytone - 2500W 2.1-Ch. Home Theater System - ...  69.00       69.00  Walmart.com  Boytone      Boytone    Friday      9  September    8           36
# 2  2017/10/24  speaker, portable, bluetooth  Boytone - 2500W 2.1-Ch. Home Theater System - ...  66.00       66.00  Walmart.com  Boytone      Boytone   Tuesday     10    October   24           43
# 3  2017/08/15  speaker, portable, bluetooth  Boytone - 2500W 2.1-Ch. Home Theater System - ...  74.99       74.99  Walmart.com  Boytone      Boytone   Tuesday      8     August   15           33
# 4  2017/09/14  speaker, portable, bluetooth  Boytone - 2500W 2.1-Ch. Home Theater System - ...  69.99       69.99  Walmart.com  Boytone      Boytone  Thursday      9  September   14           37

# %% [markdown]
# # 1.0 Data Description

# %%
df1 = df_raw.copy()

# %% [markdown]
# ## 1.1 Rename Columns

# %%
# Change to snake case
old_cols = ['Date_imp_d', 'Category_name', 'name', 'price', 'disc_price', 'merchant', 'brand',
       'manufacturer', 'Day_n', 'month', 'month_n', 'day', 'Week_Number']

snake_case = lambda x: inflection.underscore(x)

new_cols = list( map(snake_case, old_cols))
df1.columns = new_cols

# %% [markdown]
# ## 1.2 Data Dimensions

# %%
print("Número de linhas: {}".format(df1.shape[0]))
print("Número de colunas: {}".format(df1.shape[1]))
# Out:
# Número de linhas: 23151
# Número de colunas: 13

# %% [markdown]
# ## 1.3 Data Types

# %%
df1.dtypes
# Out:
# date_imp_d        object
# category_name     object
# name              object
# price            float64
# disc_price       float64
# merchant          object
# brand             object
# manufacturer      object
# day_n             object
# month              int64
# month_n           object
# day                int64
# week_number        int64
# dtype: object

# %% [markdown]
# ## 1.4 Check NA

# %%
df1.isna().sum()
# Out:
# date_imp_d           0
# category_name        0
# name                 0
# price                0
# disc_price           0
# merchant             0
# brand                0
# manufacturer     10639
# day_n                0
# month                0
# month_n              0
# day                  0
# week_number          0
# dtype: int64

# %% [markdown]
# ## 1.5 Fillout NA

# %% [markdown]
# ## 1.6 Final Check

# %%
df1.isna().sum()
# Out:
# date_imp_d           0
# category_name        0
# name                 0
# price                0
# disc_price           0
# merchant             0
# brand                0
# manufacturer     10639
# day_n                0
# month                0
# month_n              0
# day                  0
# week_number          0
# dtype: int64

# %% [markdown]
# ## 1.7 Change Types

# %%
# Change to datetime
df1['date_imp_d'] = pd.to_datetime(df1['date_imp_d'])

# %% [markdown]
# ### 1.7.1 New Types

# %%
df1.dtypes
# Out:
# date_imp_d       datetime64[ns]
# category_name            object
# name                     object
# price                   float64
# disc_price              float64
# merchant                 object
# brand                    object
# manufacturer             object
# day_n                    object
# month                     int64
# month_n                  object
# day                       int64
# week_number               int64
# dtype: object

# %% [markdown]
# ## 1.8 Descriptive Statistical

# %%
# Separação entre variáveis numéricas e categóricas
num_attributes = df1.select_dtypes( include=['int64', 'float64'])
cat_attributes = df1.select_dtypes( exclude=['int64', 'float64', 'datetime64[ns]'])

# %% [markdown]
# ### 1.8.1 Numerical Attributes

# %%
# Central tendency - mean, median
ct1 = pd.DataFrame(num_attributes.apply(np.mean)).T
ct2 = pd.DataFrame(num_attributes.apply(np.median)).T

# Dispersion - std, max, min, range, skew, kurtosis
d1 = pd.DataFrame(num_attributes.apply(np.std)).T
d2 = pd.DataFrame(num_attributes.apply(min)).T
d3 = pd.DataFrame(num_attributes.apply(max)).T
d4 = pd.DataFrame(num_attributes.apply(lambda x: x.max() - x.min())).T
d5 = pd.DataFrame(num_attributes.apply(lambda x: x.skew())).T
d6 = pd.DataFrame(num_attributes.apply(lambda x: x.kurtosis())).T

# Concatenate
m = pd.concat([d2, d3, d4, ct1, ct2, d1, d5, d6]).T.reset_index()
m.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']

m
# Out:
#     attributes  min       max     range        mean  median         std      skew   kurtosis
# 0        price  1.0  10879.95  10878.95  513.037803  199.99  859.091448  4.595160  34.411146
# 1   disc_price  1.0  10879.95  10878.95  494.104295  199.00  808.571509  4.748349  39.612839
# 2        month  1.0     12.00     11.00    7.651030    8.00    2.592787 -0.099417  -0.628859
# 3          day  1.0     31.00     30.00   15.693879   16.00    9.681413  0.032258  -1.331838
# 4  week_number  1.0     51.00     50.00   31.342750   32.00   11.316253 -0.266980  -0.648027

# %% [markdown]
# ### 1.8.2 Categorical Atribbutes

# %%
# Quantas variáveis categóricas em cada feature
cat_attributes.apply( lambda x: x.unique().shape[0] )
# Out:
# category_name     58
# name             908
# merchant           7
# brand            266
# manufacturer     236
# day_n              7
# month_n           11
# dtype: int64

# %% [markdown]
# # 2.0 Feature Engineering

# %%
df2 = df1.copy()

# %% [markdown]
# ## 2.1 Creating Hypothesis

# %%
df2.sample()
# Out:
#      date_imp_d category_name                                               name   price  disc_price     merchant brand manufacturer     day_n  month month_n  day  week_number
# 2039 2017-08-03     headphone  JBL Everest 710 Silver Over-Ear Wireless Bluet...  249.99      249.99  Bestbuy.com   Jbl          NaN  Thursday      8  August    3           31

# %% [markdown]
# 1. Qual merchant que mais vendeu?
# 2. Qual a categoria mais vendida?
# 3. Qual a marca mais vendida?
# 4. Quais os dias que mais vendem?
# 5. Quais os meses que mais vendem?
# 6. Quais as semanas que mais vendem?

# %% [markdown]
# ## 2.2 Feature Engineering

# %%
df_best = df2.loc[(df2['category_name'] == 'laptop, computer') & (df2['merchant'] == 'Bestbuy.com')]

df_agg = df_best.groupby(['name','week_number']).agg({'disc_price':'mean', 'date_imp_d': 'count'}).reset_index()

# orientando pelo preço
x_price = df_agg.pivot(index='week_number',columns='name',values='disc_price')

#orientando pela demanda
y_demand = df_agg.pivot(index='week_number',columns='name',values='date_imp_d')

# %%
df_agg.head()
# Out:
#                           name  week_number  disc_price  date_imp_d
# 0  12 MacBook (Mid 2017, Gold)           30     1599.99           1
# 1  12 MacBook (Mid 2017, Gold)           31     1551.99           8
# 2  12 MacBook (Mid 2017, Gold)           33     1454.99           2
# 3  12 MacBook (Mid 2017, Gold)           34     1551.99           2
# 4  12 MacBook (Mid 2017, Gold)           35     1474.49           4

# %% [markdown]
# # 3.0 New Data Description

# %% [markdown]
# ## 3.1 Data Dimensions

# %% [markdown]
# ### 3.1.1 x_price

# %%
print("Número de linhas: {}".format(x_price.shape[0]))
print("Número de colunas: {}".format(x_price.shape[1]))
# Out:
# Número de linhas: 26
# Número de colunas: 39

# %% [markdown]
# ### 3.1.2 y_demand

# %%
print("Número de linhas: {}".format(y_demand.shape[0]))
print("Número de colunas: {}".format(y_demand.shape[1]))
# Out:
# Número de linhas: 26
# Número de colunas: 39

# %% [markdown]
# ## 3.2 Data Types

# %%
# x_price.dtypes
# y_demand.dtypes

# %% [markdown]
# ## 3.3 Check Na

# %% [markdown]
# ### 3.3.1 x_price

# %%
x_price.isna().sum()
# Out:
# name
# 12 MacBook (Mid 2017, Gold)                                                                                                                                                                            17
# 12 MacBook (Mid 2017, Silver)                                                                                                                                                                          18
# 12.3 32GB Multi-Touch 2-in-1 Chromebook Plus                                                                                                                                                           13
# 13.3 MacBook Air (Mid 2017, Silver)                                                                                                                                                                    21
# 15.4 MacBook Pro with Touch Bar (Late 2016, Silver)                                                                                                                                                    15
# 15.4 MacBook Pro with Touch Bar (Late 2016, Space Gray)                                                                                                                                                13
# ASUS VivoBook Max X541SA 15.6Inch Laptop Intel Pentium 4GB Memory 500GB HD Matte IMR X541SA-PD0703X                                                                                                    19
# Acer - 2-in-1 15.6 Refurbished Touch-Screen Laptop - Intel Core i7 - 12GB Memory - NVIDIA GeForce 940MX - 1TB Hard Drive - Steel gray"                                                                 18
# Acer 15.6 Chromebook CB5-571-C4G4                                                                                                                                                                      12
# Alienware - R3 17.3 Laptop - Intel Core i7 - 16GB Memory - 1TB Hard Drive + 256GB Solid State Drive - Epic Silver"                                                                                     12
# Apple - MacBook Pro® - 13 Display - Intel Core i5 - 8 GB Memory - 256GB Flash Storage (Latest Model) - Silver"                                                                                         17
# Apple - MacBook Pro® - 13 Display - Intel Core i5 - 8 GB Memory - 256GB Flash Storage (Latest Model) - Space Gray"                                                                                     16
# Apple - MacBook Pro® - 13 Display - Intel Core i5 - 8 GB Memory - 512GB Flash Storage (Latest Model) - Silver"                                                                                         17
# Apple 13.3 MacBook Air ( Silver)"                                                                                                                                                                      17
# Apple MacBook - 12 - Core m5 - 8 GB RAM - 512 GB flash storage - English"                                                                                                                              10
# Apple MacBook Pro MLUQ2LL/A 13.3 Notebook - Intel Core i5 Dual-core (2 Core) 2 GHz - 8 GB LPDDR3 - 256 GB SSD - Mac OS X 10.12 Sierra - 2560 x 1600 - In-plane Switching (IPS) Technology - Silver"    18
# Apple MacBook Pro with Touch Bar - 13.3 - Core i5 - 8 GB RAM - 512 GB SSD - English"                                                                                                                    7
# Asus - 2-in-1 15.6 4K Ultra HD Touch-Screen Laptop Intel Core i7 16GB Memory NVIDIA GeForce GTX 950M - 2TB HDD + 512GB SSD - Sandblasted matte black aluminum"                                         18
# Dell - Inspiron 15.6 Laptop - Intel Core i5 - 8GB Memory - NVIDIA GeForce GTX 1050 - 1TB + 8GB Hybrid Hard Drive - Red"                                                                                10
# Dell - XPS 2-in-1 13.3 Touch-Screen Laptop - Intel Core i7 - 16GB Memory - 256GB Solid State Drive - Silver"                                                                                           10
# Dell XPS 15 15.6 4K Touchcreen Laptop Intel i7-6700HQ 16GB 1TB SSD GTX 960M"                                                                                                                           18
# Details About Alienware 13 R3 Aw13r3/13.3 Fhd/i77700hq/nvidia Gtx 1060/16gb/512gb Ssd"                                                                                                                 11
# Details About Alienware 15 R3 Aw15r3/15.6 Fhd/i77700hq/nvidia Gtx1070/16gb/1tb Hdd+128gb Ssd"                                                                                                          12
# Details About Apple Macbook Air 13.3 Laptop (early 2015) 2.2ghz Core I7 8gb 256gb"                                                                                                                     19
# Details About Asus Q304 13.3 Laptop I5 2.5 Ghz 6gb 1tb Hdd Win 10 (q304uabhi5t11)"                                                                                                                     12
# Details About Dell Inspiron I75675650blkpus 15.6 Laptop I57300hq"                                                                                                                                      19
# Details About Openbox Excellent: Asus Rog Gl502vm 15.6 Laptop Intel Core I7 12gb Me..."                                                                                                                12
# Details About Razer Blade Laptop 14 Full Hd (i77700hq"                                                                                                                                                 13
# Ginsu BESTBUY5580020 Lenovo Ideapad 11.6 Laptop"                                                                                                                                                        8
# HP - ProBook 14 Laptop - Intel Core i5 - 4GB Memory - 500GB Hard Drive - Black"                                                                                                                        10
# HP 15-AY103DX 15.6 Touchscreen Touch Screen HD Laptop Notebook PC Computer 7th Gen i5-7200U Kaby Lake 8GB Memory 1TB HDD Hard Drive Windows 10"                                                        16
# Lenovo - 100S-14IBR 14 Laptop - Intel Celeron - 2GB Memory - 32GB eMMC Flash Memory - Navy blue"                                                                                                       13
# Lenovo - Yoga 710 2-in-1 11.6 Touch-Screen Laptop - Intel Core i5 - 8GB Memory - 128GB Solid State Drive - Silver Tablet PC Notebook 80V6000PUS"                                                       11
# Lenovo 80TX0007US Y 710-11ISK 11.6-Inch FHD Touch Laptop (Pentium 4405Y, 4 GB Ram, 128 GB SSD, Windows 10), SilverNotebook PC Computer Tablet Touchscreen Screen 2-in-1                                19
# Lenovo Flex 4 1470 80SA0000US 2-in-1 - 14 HD Touch - Pentium 4405U 2.1Ghz - 4GB - 500GB"                                                                                                               13
# MSI - WS Series 15.6 Laptop - Intel Core i7 - 16GB Memory - 256GB Solid State Drive + 2TB Hard Drive - Aluminum Black"                                                                                 13
# New Asus Q524u 15.6fhd 2in1 Touch I77500u 3.5ghz 16gb Ddr4 2tb Hd 940mx2gb W10"                                                                                                                        14
# Razer - Blade Pro 17.3 4K Ultra HD Touch-Screen Laptop - Intel Core i7 - 32GB Memory - NVIDIA GeForce GTX 1080 - 1TB SSD - Black"                                                                      13
# Samsung - Notebook 5 15.6 Touch-Screen Laptop - Intel Core i5 - 8GB Memory - NVIDIA GeForce 920MX - 1TB Hard Drive - Solid black"                                                                      11
# dtype: int64

# %% [markdown]
# ### 3.3.2 y_demand

# %%
y_demand.isna().sum()
# Out:
# name
# 12 MacBook (Mid 2017, Gold)                                                                                                                                                                            17
# 12 MacBook (Mid 2017, Silver)                                                                                                                                                                          18
# 12.3 32GB Multi-Touch 2-in-1 Chromebook Plus                                                                                                                                                           13
# 13.3 MacBook Air (Mid 2017, Silver)                                                                                                                                                                    21
# 15.4 MacBook Pro with Touch Bar (Late 2016, Silver)                                                                                                                                                    15
# 15.4 MacBook Pro with Touch Bar (Late 2016, Space Gray)                                                                                                                                                13
# ASUS VivoBook Max X541SA 15.6Inch Laptop Intel Pentium 4GB Memory 500GB HD Matte IMR X541SA-PD0703X                                                                                                    19
# Acer - 2-in-1 15.6 Refurbished Touch-Screen Laptop - Intel Core i7 - 12GB Memory - NVIDIA GeForce 940MX - 1TB Hard Drive - Steel gray"                                                                 18
# Acer 15.6 Chromebook CB5-571-C4G4                                                                                                                                                                      12
# Alienware - R3 17.3 Laptop - Intel Core i7 - 16GB Memory - 1TB Hard Drive + 256GB Solid State Drive - Epic Silver"                                                                                     12
# Apple - MacBook Pro® - 13 Display - Intel Core i5 - 8 GB Memory - 256GB Flash Storage (Latest Model) - Silver"                                                                                         17
# Apple - MacBook Pro® - 13 Display - Intel Core i5 - 8 GB Memory - 256GB Flash Storage (Latest Model) - Space Gray"                                                                                     16
# Apple - MacBook Pro® - 13 Display - Intel Core i5 - 8 GB Memory - 512GB Flash Storage (Latest Model) - Silver"                                                                                         17
# Apple 13.3 MacBook Air ( Silver)"                                                                                                                                                                      17
# Apple MacBook - 12 - Core m5 - 8 GB RAM - 512 GB flash storage - English"                                                                                                                              10
# Apple MacBook Pro MLUQ2LL/A 13.3 Notebook - Intel Core i5 Dual-core (2 Core) 2 GHz - 8 GB LPDDR3 - 256 GB SSD - Mac OS X 10.12 Sierra - 2560 x 1600 - In-plane Switching (IPS) Technology - Silver"    18
# Apple MacBook Pro with Touch Bar - 13.3 - Core i5 - 8 GB RAM - 512 GB SSD - English"                                                                                                                    7
# Asus - 2-in-1 15.6 4K Ultra HD Touch-Screen Laptop Intel Core i7 16GB Memory NVIDIA GeForce GTX 950M - 2TB HDD + 512GB SSD - Sandblasted matte black aluminum"                                         18
# Dell - Inspiron 15.6 Laptop - Intel Core i5 - 8GB Memory - NVIDIA GeForce GTX 1050 - 1TB + 8GB Hybrid Hard Drive - Red"                                                                                10
# Dell - XPS 2-in-1 13.3 Touch-Screen Laptop - Intel Core i7 - 16GB Memory - 256GB Solid State Drive - Silver"                                                                                           10
# Dell XPS 15 15.6 4K Touchcreen Laptop Intel i7-6700HQ 16GB 1TB SSD GTX 960M"                                                                                                                           18
# Details About Alienware 13 R3 Aw13r3/13.3 Fhd/i77700hq/nvidia Gtx 1060/16gb/512gb Ssd"                                                                                                                 11
# Details About Alienware 15 R3 Aw15r3/15.6 Fhd/i77700hq/nvidia Gtx1070/16gb/1tb Hdd+128gb Ssd"                                                                                                          12
# Details About Apple Macbook Air 13.3 Laptop (early 2015) 2.2ghz Core I7 8gb 256gb"                                                                                                                     19
# Details About Asus Q304 13.3 Laptop I5 2.5 Ghz 6gb 1tb Hdd Win 10 (q304uabhi5t11)"                                                                                                                     12
# Details About Dell Inspiron I75675650blkpus 15.6 Laptop I57300hq"                                                                                                                                      19
# Details About Openbox Excellent: Asus Rog Gl502vm 15.6 Laptop Intel Core I7 12gb Me..."                                                                                                                12
# Details About Razer Blade Laptop 14 Full Hd (i77700hq"                                                                                                                                                 13
# Ginsu BESTBUY5580020 Lenovo Ideapad 11.6 Laptop"                                                                                                                                                        8
# HP - ProBook 14 Laptop - Intel Core i5 - 4GB Memory - 500GB Hard Drive - Black"                                                                                                                        10
# HP 15-AY103DX 15.6 Touchscreen Touch Screen HD Laptop Notebook PC Computer 7th Gen i5-7200U Kaby Lake 8GB Memory 1TB HDD Hard Drive Windows 10"                                                        16
# Lenovo - 100S-14IBR 14 Laptop - Intel Celeron - 2GB Memory - 32GB eMMC Flash Memory - Navy blue"                                                                                                       13
# Lenovo - Yoga 710 2-in-1 11.6 Touch-Screen Laptop - Intel Core i5 - 8GB Memory - 128GB Solid State Drive - Silver Tablet PC Notebook 80V6000PUS"                                                       11
# Lenovo 80TX0007US Y 710-11ISK 11.6-Inch FHD Touch Laptop (Pentium 4405Y, 4 GB Ram, 128 GB SSD, Windows 10), SilverNotebook PC Computer Tablet Touchscreen Screen 2-in-1                                19
# Lenovo Flex 4 1470 80SA0000US 2-in-1 - 14 HD Touch - Pentium 4405U 2.1Ghz - 4GB - 500GB"                                                                                                               13
# MSI - WS Series 15.6 Laptop - Intel Core i7 - 16GB Memory - 256GB Solid State Drive + 2TB Hard Drive - Aluminum Black"                                                                                 13
# New Asus Q524u 15.6fhd 2in1 Touch I77500u 3.5ghz 16gb Ddr4 2tb Hd 940mx2gb W10"                                                                                                                        14
# Razer - Blade Pro 17.3 4K Ultra HD Touch-Screen Laptop - Intel Core i7 - 32GB Memory - NVIDIA GeForce GTX 1080 - 1TB SSD - Black"                                                                      13
# Samsung - Notebook 5 15.6 Touch-Screen Laptop - Intel Core i5 - 8GB Memory - NVIDIA GeForce 920MX - 1TB Hard Drive - Solid black"                                                                      11
# dtype: int64

# %% [markdown]
# ## 3.4 Fillout Na

# %% [markdown]
# ### 3.4.1 x_price

# %%
median = np.round(x_price.median(),2)
x_price.fillna(median, inplace=True)

# %% [markdown]
# ### 3.4.2 y_demand

# %%
y_demand.fillna(0, inplace=True)

# %% [markdown]
# ## 3.5 Descriptive Statistical

# %% [markdown]
# ### 3.5.1 x_price

# %%
# Central Tendency - mean, meadina 
ct1 = pd.DataFrame( x_price.apply( np.mean ) ).T
ct2 = pd.DataFrame( x_price.apply( np.median ) ).T

# dispersion - std, min, max, range, skew, kurtosis
d1 = pd.DataFrame( x_price.apply( np.std ) ).T 
d2 = pd.DataFrame( x_price.apply( min ) ).T 
d3 = pd.DataFrame( x_price.apply( max ) ).T 
d4 = pd.DataFrame( x_price.apply( lambda x: x.max() - x.min() ) ).T 
d5 = pd.DataFrame( x_price.apply( lambda x: x.skew() ) ).T 
d6 = pd.DataFrame( x_price.apply( lambda x: x.kurtosis() ) ).T 

# concatenar
m = pd.concat( [d2, d3, d4, ct1, ct2, d1, d5, d6] ).T.reset_index()
m.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']
m
# Out:
#                                            attributes       min      max     range         mean   median         std      skew   kurtosis
# 0                         12 MacBook (Mid 2017, Gold)  1454.990  1599.99   145.000  1547.124615  1551.99   25.648346 -2.457686   8.310054
# 1                       12 MacBook (Mid 2017, Silver)  1234.990  1299.99    65.000  1295.990000  1299.99   14.317821 -3.735032  13.784949
# 2        12.3 32GB Multi-Touch 2-in-1 Chromebook Plus   372.995   449.00    76.005   413.189808   415.50   15.423120 -1.054924   2.830858
# 3                 13.3 MacBook Air (Mid 2017, Silver)   911.990   969.99    58.000   949.297692   949.99    8.393080 -2.975611  16.702015
# 4   15.4 MacBook Pro with Touch Bar (Late 2016, Si...  2327.990  2799.99   472.000  2607.393846  2618.99  112.833610 -1.131897   2.049122
# 5   15.4 MacBook Pro with Touch Bar (Late 2016, Sp...  2023.990  2599.99   576.000  2346.913077  2353.99  122.523757 -0.274833   1.347179
# 6   ASUS VivoBook Max X541SA 15.6Inch Laptop Intel...   237.490   313.49    76.000   299.720769   304.99   16.347918 -2.916993   8.218479
# 7   Acer - 2-in-1 15.6 Refurbished Touch-Screen La...   764.990   899.99   135.000   834.028462   829.99   27.804926  0.937281   2.943939
# 8                   Acer 15.6 Chromebook CB5-571-C4G4   199.990   249.00    49.010   242.479231   249.00   14.017001 -2.306458   4.514429
# 9   Alienware - R3 17.3 Laptop - Intel Core i7 - 1...  1599.990  1899.99   300.000  1879.643846  1899.99   71.165540 -3.486137  11.301211
# 10  Apple - MacBook Pro® - 13 Display - Intel Core...  1315.990  1454.99   139.000  1402.393846  1409.99   32.489945 -1.674626   2.634043
# 11  Apple - MacBook Pro® - 13 Display - Intel Core...  1315.990  1454.99   139.000  1386.816923  1387.49   31.076191 -0.336021   1.248185
# 12  Apple - MacBook Pro® - 13 Display - Intel Core...  1794.490  1999.99   205.500  1882.970769  1879.99   35.218134  1.074956   5.009074
# 13                  Apple 13.3 MacBook Air ( Silver)"   600.495  1234.99   634.495  1105.894231  1139.99  149.742908 -3.061454   8.881266
# 14  Apple MacBook - 12 - Core m5 - 8 GB RAM - 512 ...  1079.990  1519.99   440.000  1337.342564  1365.99  132.157268 -0.634398  -0.579783
# 15  Apple MacBook Pro MLUQ2LL/A 13.3 Notebook - In...   700.495  1432.49   731.995  1224.221154  1255.99  157.354284 -2.875711   8.321049
# 16  Apple MacBook Pro with Touch Bar - 13.3 - Core...  1610.740  1999.99   389.250  1770.047692  1745.99  108.099409  0.743867  -0.130056
# 17  Asus - 2-in-1 15.6 4K Ultra HD Touch-Screen La...  1091.990  1329.99   238.000  1238.105385  1236.99   42.173020 -0.901318   5.771187
# 18  Dell - Inspiron 15.6 Laptop - Intel Core i5 - ...   719.990   799.99    80.000   790.759231   799.99   20.176734 -2.260445   4.782109
# 19  Dell - XPS 2-in-1 13.3 Touch-Screen Laptop - I...   700.495  1399.99   699.495  1110.201923  1112.49  138.793966 -1.562021   4.845185
# 20  Dell XPS 15 15.6 4K Touchcreen Laptop Intel i7...   900.495  2199.99  1299.495  1599.067308  1634.99  229.475939 -1.567445   6.894041
# 21  Details About Alienware 13 R3 Aw13r3/13.3 Fhd/...  1349.990  1799.99   450.000  1652.893846  1664.99   82.682783 -1.649767   6.363103
# 22  Details About Alienware 15 R3 Aw15r3/15.6 Fhd/...  1601.990  1899.99   298.000  1774.836154  1780.49   58.292823 -0.661292   3.143959
# 23  Details About Apple Macbook Air 13.3 Laptop (e...   727.490   799.99    72.500   795.509231   799.99   14.819738 -4.064744  17.682020
# 24  Details About Asus Q304 13.3 Laptop I5 2.5 Ghz...   441.990   657.99   216.000   522.220769   508.49   56.213062  1.427662   1.542973
# 25  Details About Dell Inspiron I75675650blkpus 15...   763.990   868.49   104.500   848.874615   854.99   21.648995 -2.953601   9.045249
# 26  Details About Openbox Excellent: Asus Rog Gl50...  1063.490  1249.99   186.500  1151.163077  1146.74   40.106695  0.633079   1.697089
# 27  Details About Razer Blade Laptop 14 Full Hd (i...  1050.495  2099.99  1049.495  1954.220962  1994.99  185.631208 -4.684702  23.048475
# 28   Ginsu BESTBUY5580020 Lenovo Ideapad 11.6 Laptop"   123.490   189.99    66.500   164.623846   162.74   15.774571 -0.176079   0.585055
# 29  HP - ProBook 14 Laptop - Intel Core i5 - 4GB M...   799.990   819.99    20.000   819.220769   819.99    3.846154 -5.099020  26.000000
# 30  HP 15-AY103DX 15.6 Touchscreen Touch Screen HD...   427.490   499.99    72.500   464.413077   463.74   16.265639  0.360525   2.085746
# 31  Lenovo - 100S-14IBR 14 Laptop - Intel Celeron ...   170.990   229.99    59.000   209.663077   218.49   18.610348 -1.514704   0.593616
# 32  Lenovo - Yoga 710 2-in-1 11.6 Touch-Screen Lap...   513.990   664.99   151.000   602.970769   601.49   38.807583 -0.285576   0.364509
# 33  Lenovo 80TX0007US Y 710-11ISK 11.6-Inch FHD To...   314.990   474.99   160.000   414.605385   415.99   28.666621 -1.127907   5.748375
# 34  Lenovo Flex 4 1470 80SA0000US 2-in-1 - 14 HD T...   316.990   383.99    67.000   343.163077   337.49   17.414043  1.351659   0.773987
# 35  MSI - WS Series 15.6 Laptop - Intel Core i7 - ...  2299.990  2399.99   100.000  2396.143846  2399.99   19.230769 -5.099020  26.000000
# 36  New Asus Q524u 15.6fhd 2in1 Touch I77500u 3.5g...   554.990   949.99   395.000   847.470769   853.74   73.683670 -2.293481   8.874468
# 37  Razer - Blade Pro 17.3 4K Ultra HD Touch-Scree...  3674.990  4399.99   725.000  4164.797692  4179.99  148.806022 -1.055879   3.659037
# 38  Samsung - Notebook 5 15.6 Touch-Screen Laptop ...   569.990   617.49    47.500   604.682308   610.99   13.731685 -1.800761   2.141848

# %% [markdown]
# ### 3.5.2 y_demand

# %%
# Central Tendency - mean, meadina 
ct1 = pd.DataFrame( y_demand.apply( np.mean ) ).T
ct2 = pd.DataFrame( y_demand.apply( np.median ) ).T

# dispersion - std, min, max, range, skew, kurtosis
d1 = pd.DataFrame( y_demand.apply( np.std ) ).T 
d2 = pd.DataFrame( y_demand.apply( min ) ).T 
d3 = pd.DataFrame( y_demand.apply( max ) ).T 
d4 = pd.DataFrame( y_demand.apply( lambda x: x.max() - x.min() ) ).T 
d5 = pd.DataFrame( y_demand.apply( lambda x: x.skew() ) ).T 
d6 = pd.DataFrame( y_demand.apply( lambda x: x.kurtosis() ) ).T 

# concatenar
m = pd.concat( [d2, d3, d4, ct1, ct2, d1, d5, d6] ).T.reset_index()
m.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']
m
# Out:
#                                            attributes  min   max  range      mean  median       std      skew  kurtosis
# 0                         12 MacBook (Mid 2017, Gold)  0.0   8.0    8.0  0.961538     0.0  1.764626  2.738840  9.024976
# 1                       12 MacBook (Mid 2017, Silver)  0.0   2.0    2.0  0.384615     0.0  0.624926  1.474017  1.189701
# 2        12.3 32GB Multi-Touch 2-in-1 Chromebook Plus  0.0   4.0    4.0  1.038462     0.5  1.125945  0.606680 -0.428079
# 3                 13.3 MacBook Air (Mid 2017, Silver)  0.0   2.0    2.0  0.384615     0.0  0.788227  1.658711  0.807453
# 4   15.4 MacBook Pro with Touch Bar (Late 2016, Si...  0.0   6.0    6.0  1.153846     0.0  1.609881  1.437577  1.673167
# 5   15.4 MacBook Pro with Touch Bar (Late 2016, Sp...  0.0  12.0   12.0  3.230769     1.0  3.885948  0.951022 -0.225438
# 6   ASUS VivoBook Max X541SA 15.6Inch Laptop Intel...  0.0   2.0    2.0  0.538462     0.0  0.887120  1.105353 -0.849951
# 7   Acer - 2-in-1 15.6 Refurbished Touch-Screen La...  0.0   2.0    2.0  0.384615     0.0  0.624926  1.474017  1.189701
# 8                   Acer 15.6 Chromebook CB5-571-C4G4  0.0   4.0    4.0  0.769231     1.0  0.932643  1.711207  4.066693
# 9   Alienware - R3 17.3 Laptop - Intel Core i7 - 1...  0.0   2.0    2.0  0.615385     1.0  0.624926  0.534925 -0.518213
# 10  Apple - MacBook Pro® - 13 Display - Intel Core...  0.0   6.0    6.0  1.076923     0.0  1.685300  1.510368  1.459409
# 11  Apple - MacBook Pro® - 13 Display - Intel Core...  0.0   6.0    6.0  1.115385     0.0  1.671640  1.485283  1.450766
# 12  Apple - MacBook Pro® - 13 Display - Intel Core...  0.0   6.0    6.0  0.730769     0.0  1.317273  2.680292  8.923337
# 13                  Apple 13.3 MacBook Air ( Silver)"  0.0   6.0    6.0  1.153846     0.0  1.769231  1.345266  0.665215
# 14  Apple MacBook - 12 - Core m5 - 8 GB RAM - 512 ...  0.0   9.0    9.0  2.615385     2.5  2.558198  0.604769 -0.449733
# 15  Apple MacBook Pro MLUQ2LL/A 13.3 Notebook - In...  0.0   4.0    4.0  0.692308     0.0  1.101371  1.402809  1.215839
# 16  Apple MacBook Pro with Touch Bar - 13.3 - Core...  0.0  12.0   12.0  3.576923     4.0  3.078125  0.761595  0.510283
# 17  Asus - 2-in-1 15.6 4K Ultra HD Touch-Screen La...  0.0   4.0    4.0  0.692308     0.0  1.101371  1.402809  1.215839
# 18  Dell - Inspiron 15.6 Laptop - Intel Core i5 - ...  0.0   4.0    4.0  1.307692     1.0  1.352184  0.782681 -0.520118
# 19  Dell - XPS 2-in-1 13.3 Touch-Screen Laptop - I...  0.0   4.0    4.0  1.346154     1.5  1.299180  0.639999 -0.367121
# 20  Dell XPS 15 15.6 4K Touchcreen Laptop Intel i7...  0.0   2.0    2.0  0.538462     0.0  0.842650  1.100654 -0.693274
# 21  Details About Alienware 13 R3 Aw13r3/13.3 Fhd/...  0.0   4.0    4.0  1.153846     1.0  1.199112  0.821121  0.137298
# 22  Details About Alienware 15 R3 Aw15r3/15.6 Fhd/...  0.0   4.0    4.0  1.153846     1.5  1.166596  0.452252 -0.752199
# 23  Details About Apple Macbook Air 13.3 Laptop (e...  0.0   2.0    2.0  0.384615     0.0  0.683707  1.597602  1.213008
# 24  Details About Asus Q304 13.3 Laptop I5 2.5 Ghz...  0.0   4.0    4.0  1.153846     2.0  1.133148  0.350929 -0.727992
# 25  Details About Dell Inspiron I75675650blkpus 15...  0.0   4.0    4.0  0.615385     0.0  1.076923  1.644545  2.058359
# 26  Details About Openbox Excellent: Asus Rog Gl50...  0.0   2.0    2.0  1.000000     1.0  0.960769  0.000000 -2.072011
# 27  Details About Razer Blade Laptop 14 Full Hd (i...  0.0   2.0    2.0  1.000000     1.0  1.000000  0.000000 -2.173913
# 28   Ginsu BESTBUY5580020 Lenovo Ideapad 11.6 Laptop"  0.0   4.0    4.0  1.307692     2.0  1.029161  0.218238 -0.086548
# 29  HP - ProBook 14 Laptop - Intel Core i5 - 4GB M...  0.0   2.0    2.0  0.692308     1.0  0.605693  0.287231 -0.506365
# 30  HP 15-AY103DX 15.6 Touchscreen Touch Screen HD...  0.0   4.0    4.0  0.692308     0.0  1.029161  1.580897  2.390170
# 31  Lenovo - 100S-14IBR 14 Laptop - Intel Celeron ...  0.0   2.0    2.0  0.961538     0.5  0.979826  0.081727 -2.117614
# 32  Lenovo - Yoga 710 2-in-1 11.6 Touch-Screen Lap...  0.0   4.0    4.0  1.153846     1.5  1.098681  0.413441 -0.450744
# 33  Lenovo 80TX0007US Y 710-11ISK 11.6-Inch FHD To...  0.0   4.0    4.0  0.615385     0.0  1.076923  1.644545  2.058359
# 34  Lenovo Flex 4 1470 80SA0000US 2-in-1 - 14 HD T...  0.0   4.0    4.0  1.153846     1.0  1.261632  0.667437 -0.428047
# 35  MSI - WS Series 15.6 Laptop - Intel Core i7 - ...  0.0   2.0    2.0  0.576923     0.5  0.630816  0.667437 -0.428047
# 36  New Asus Q524u 15.6fhd 2in1 Touch I77500u 3.5g...  0.0   4.0    4.0  1.000000     0.0  1.240347  1.027740  0.259511
# 37  Razer - Blade Pro 17.3 4K Ultra HD Touch-Scree...  0.0   4.0    4.0  1.000000     0.5  1.208941  1.109936  0.610472
# 38  Samsung - Notebook 5 15.6 Touch-Screen Laptop ...  0.0   4.0    4.0  1.269231     2.0  1.226555  0.507032 -0.421253

# %% [markdown]
# # 3.0 Análise Exploratória de Dados

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,1,1)
aux = pd.DataFrame(x_price.apply(lambda x: x.median())).head(10).reset_index()
aux.columns = ['name','price']
sns.barplot(x='name', y='price',data=aux)
plt.xticks([])

plt.subplot(2,1,2)
aux2 = pd.DataFrame(y_demand.apply(lambda x: x.sum())).head(10).reset_index()
aux2.columns = ['name','demand']
plt.xticks(rotation=90)
sns.barplot(x='name', y='demand',data=aux2)
# Out:
# <AxesSubplot:xlabel='name', ylabel='demand'>

# %% [markdown]
# ## 3.2 Análise Bivariada

# %% [markdown]
# ### 1. Qual merchant que mais vendeu?

# %%
# Agrupando por merchant
aux = df3[['merchant', 'date_imp_d']].groupby('merchant').count().sort_values(by='date_imp_d', ascending=False).reset_index()
sns.barplot( x='merchant', y='date_imp_d', data=aux );

# %% [markdown]
# ### 2. Qual categoria mais vendida?

# %%
# Top 5
aux1 = df3[['category_name', 'date_imp_d']].groupby('category_name').count().sort_values(by='date_imp_d', ascending=False).head().reset_index()
sns.barplot( x='category_name', y='date_imp_d', data=aux1 );

# %%
#4. Quais os dias que mais vendem?
#5. Quais os meses que mais vendem?
#6. Quais as semanas que mais vendem?

# %% [markdown]
# ### 3. Qual a marca mais vendida?

# %%
# Top 5
aux2 = df3[['brand', 'date_imp_d']].groupby('brand').count().sort_values(by='date_imp_d', ascending=False).head().reset_index()
sns.barplot( x='brand', y='date_imp_d', data=aux2 );

# %% [markdown]
# ### 4. Quais os dias da semana que mais vendem?

# %%
aux3 = df3[['day_n', 'date_imp_d']].groupby('day_n').count().sort_values(by='date_imp_d', ascending=False).reset_index()
sns.barplot( x='day_n', y='date_imp_d', data=aux3 );

# %% [markdown]
# ### 5. Quais os meses que mais vendem?

# %%
# Top 5
aux3 = df3[['month', 'date_imp_d']].groupby('month').count().sort_values(by='date_imp_d', ascending=False).head().reset_index()
sns.barplot( x='month', y='date_imp_d', data=aux3 );

# %% [markdown]
# ### 6. Quais as semanas que mais vendem?

# %%
# Top 5
aux3 = df3[['week_number', 'date_imp_d']].groupby('week_number').count().sort_values(by='date_imp_d', ascending=False).head().reset_index()
sns.barplot( x='week_number', y='date_imp_d', data=aux3 );

# %% [markdown]
# # 4.0 Data Preparation

# %% [markdown]
# # 5.0 Machine Learning Modelling

# %%
x_price1 = x_price['Acer 15.6 Chromebook CB5-571-C4G4']
y_demand1 = y_demand['Acer 15.6 Chromebook CB5-571-C4G4']


X = sm.add_constant(x_price1)
model = sm.OLS(y_demand1, X)
results = model.fit()


results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     Acer 15.6 Chromebook CB5-571-C4G4   R-squared:                       0.162
# Model:                                           OLS   Adj. R-squared:                  0.127
# Method:                                Least Squares   F-statistic:                     4.627
# Date:                               Sat, 02 Sep 2023   Prob (F-statistic):             0.0417
# Time:                                       10:24:15   Log-Likelihood:                -32.787
# No. Observations:                                 26   AIC:                             69.57
# Df Residuals:                                     24   BIC:                             72.09
# Df Model:                                          1
# Covariance Type:                           nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                 7.2558      3.020      2.402      0.024       1.022      13.490
# Acer 15.6 Chromebook CB5-571-C4G4    -0.0268      0.012     -2.151      0.042      -0.052      -0.001
# ==============================================================================
# Omnibus:                       20.404   Durbin-Watson:                   1.614
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.512
# Skew:                           1.718   Prob(JB):                     6.44e-07
# Kurtosis:                       6.810   Cond. No.                     4.21e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.21e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
results_values_laptop = {
    "name": [],
    "price_elastity": [],
    "price_mean": [],
    "quantity_mean": [],
    "intercept": [],
    "slope": [],
    "rsquared": [],
    "p_value": []

}

df = pd.DataFrame()
for column in x_price.columns:
    #print(column)
    list_price = []
    list_demand = []
    column_points = []
    for i in range(len(x_price[column])):
        column_points.append({'x_price': x_price.reset_index(drop=True)[column][i],
                            'y_demand': y_demand.reset_index(drop=True)[column][i]})
        
        list_price.append(column_points[i]['x_price'])
        list_demand.append(column_points[i]['y_demand'])


    X = sm.add_constant(list_price)
    model = sm.OLS(list_demand, X)
    results = model.fit()

    if results.f_pvalue < 0.05:
        rsquared = results.rsquared
        pvalue = results.f_pvalue
        intercept, slope = results.params
        
        mean_price = np.round(np.mean(list_price),2)
        mean_quantity = np.round(np.mean(list_demand),2)

        price_elastity = slope*(mean_price/mean_quantity)

        results_values_laptop['name'].append(column)
        results_values_laptop['price_elastity'].append(price_elastity)
        results_values_laptop['rsquared'].append(rsquared)
        results_values_laptop['p_value'].append(pvalue)
        results_values_laptop['intercept'].append(intercept)
        results_values_laptop['slope'].append(slope)
        results_values_laptop['price_mean'].append(mean_price)
        results_values_laptop['quantity_mean'].append(mean_quantity)
df_elastity = pd.DataFrame(results_values_laptop)

# %%
df_elastity
# Out:
#                                                 name  price_elastity  price_mean  quantity_mean  intercept     slope  rsquared   p_value
# 0                      12 MacBook (Mid 2017, Silver)      -65.906473     1295.99           0.38  25.429075 -0.019325  0.196027  0.023508
# 1  ASUS VivoBook Max X541SA 15.6Inch Laptop Intel...      -15.993905      299.72           0.54   9.175192 -0.028816  0.281984  0.005251
# 2                  Acer 15.6 Chromebook CB5-571-C4G4       -8.424147      242.48           0.77   7.255804 -0.026751  0.161645  0.041743
# 3  Apple MacBook Pro MLUQ2LL/A 13.3 Notebook - In...       -6.038766     1224.22           0.69   4.859060 -0.003404  0.236464  0.011774
# 4  Dell - Inspiron 15.6 Laptop - Intel Core i5 - ...      -23.162684      790.76           1.31  31.650779 -0.038372  0.327839  0.002237
# 5  Details About Apple Macbook Air 13.3 Laptop (e...      -68.993714      795.51           0.38  26.602201 -0.032957  0.510312  0.000041
# 6  Lenovo - 100S-14IBR 14 Laptop - Intel Celeron ...       -6.059004      209.66           0.96   6.778268 -0.027743  0.277667  0.005677

# %% [markdown]
# # 6.0 Business Performance
